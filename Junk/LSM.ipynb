# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np
from IPython.display import display
def display_matrix(m):
    display(sympy.Matrix(m))
import sympy

sympy.init_printing()

# %%
S0 = 102
T = 1
mu = 0.05
sigma = 0.2
lam = 1
I = 5
m = 0
v = 0.3
paths = 5
K = 99
df = np.exp(-mu*T)

# %%
def matrix(paths):
    matrix = np.zeros((paths, I))
    for k in range(paths):
        X = np.zeros(I)
        S = np.zeros(I)

        X[0] = np.log(S0)
        S[0] = S0
        dt = T / I
    
        for i in range(1,I):
            Z = np.random.standard_normal()
            N = np.random.poisson(lam * dt)
            Y = np.exp(np.random.normal(m,v,N))
    
            if N == 0:
                M = 0
    
            else:
                for j in range(N):
                    M = np.sum(np.log(Y))
                    
            X[i] = X[i-1] + (mu - 0.5 * sigma ** 2) * dt + sigma * np.sqrt(dt) * Z + M
            S[i] = np.exp(X[i])
        matrix[k] = S
    return matrix

S = matrix(paths)
S.shape
# Out:
# (5, 5)

# %%
H = np.maximum(K - S, 0)  # intrinsic values for put option
V = np.zeros_like(H)  # value matrix
V[:, -1] = H[:, -1] # set value at maturity equal to intrinsic value
# Valuation by LS Method
for t in range(I - 2, 0, -1): #start at t = I-2 and go backwards (since we already set t = I-1 to intrinsic value)
    good_paths = H[:, t] > 0  # paths where the intrinsic value is positive
    # the regression is performed only on these paths
    rg = np.polyfit(S[good_paths, t], V[good_paths, t + 1] * df, 3)  # polynomial regression
    C = np.polyval(rg, S[good_paths, t])  # evaluation of regression

    exercise = np.zeros(len(good_paths), dtype=bool)  # initialize
    exercise[good_paths] = H[good_paths, t] > C  # paths where it is optimal to exercise

    V[exercise, t] = H[exercise, t]  # set V equal to H where it is optimal to exercise
    V[exercise, t + 1 :] = 0  # set future cash flows, for that path, equal to zero
    discount_path = V[:, t] == 0  # paths where we didn't exercise
    V[discount_path, t] = V[discount_path, t + 1] * df  # set V[t] in continuation region

V0 = np.mean(V[:, 1]) * df  # discounted expectation of V[t=1]
print('The value of the American put option is: ', V0)

V.shape
# Out:
# /Users/philipgadereumert/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/philipgadereumert/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/philipgadereumert/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# The value of the American put option is:  5.639602533862314
# (5, 5)

# %%
def LSM(K, S, I, df, basis):
    H = np.maximum(K - S, 0)  # intrinsic values for put option
    V = np.zeros_like(H)  # value matrix
    V[:, -1] = H[:, -1] # set value at maturity equal to intrinsic value
    # Valuation by LS Method
    for t in range(I - 2, 0, -1): #start at t = I-2 and go backwards (since we already set t = I-1 to intrinsic value)
        good_paths = H[:, t] > 0  # paths where the intrinsic value is positive
        # the regression is performed only on these paths
        if basis == 'poly':
            rg = np.polyfit(S[good_paths, t], V[good_paths, t + 1] * df, 3)  # polynomial regression
            C = np.polyval(rg, S[good_paths, t])  # evaluation of regression
        elif basis == 'legendre':
            rg = np.polynomial.legendre.legfit(S[good_paths, t], V[good_paths, t + 1] * df, 3)
            C = np.polynomial.legendre.legval(S[good_paths, t], rg)
        else:
            rg = np.polynomial.hermite.hermfit(S[good_paths, t], V[good_paths, t + 1] * df, 3)
            C = np.polynomial.hermite.hermval(S[good_paths, t], rg)

        exercise = np.zeros(len(good_paths), dtype=bool)  # initialize
        exercise[good_paths] = H[good_paths, t] > C  # paths where it is optimal to exercise

        V[exercise, t] = H[exercise, t]  # set V equal to H where it is optimal to exercise
        V[exercise, t + 1 :] = 0  # set future cash flows, for that path, equal to zero
        discount_path = V[:, t] == 0  # paths where we didn't exercise
        V[discount_path, t] = V[discount_path, t + 1] * df  # set V[t] in continuation region

    V0 = np.mean(V[:, 1]) * df  # discounted expectation of V[t=1]
    print('The value of the American put option is: ', V0)
    return V0

# %%
for basis in ('poly', 'legendre', 'hermite'):
          LSM(K, S, I, df, basis)
# Out:
# The value of the American put option is:  5.639602533862314
# The value of the American put option is:  5.639602533862314
# The value of the American put option is:  5.639602533862314
# /var/folders/3l/9tdvgjyd6v12z560tdqxmwlm0000gn/T/ipykernel_22957/2160433033.py:2: RankWarning: Polyfit may be poorly conditioned
#   LSM(K, S, I, df, basis)
# /var/folders/3l/9tdvgjyd6v12z560tdqxmwlm0000gn/T/ipykernel_22957/2160433033.py:2: RankWarning: Polyfit may be poorly conditioned
#   LSM(K, S, I, df, basis)
# /var/folders/3l/9tdvgjyd6v12z560tdqxmwlm0000gn/T/ipykernel_22957/2160433033.py:2: RankWarning: Polyfit may be poorly conditioned
#   LSM(K, S, I, df, basis)
# /Users/philipgadereumert/opt/anaconda3/lib/python3.9/site-packages/numpy/polynomial/legendre.py:1411: RankWarning: The fit may be poorly conditioned
#   return pu._fit(legvander, x, y, deg, rcond, full, w)
# /Users/philipgadereumert/opt/anaconda3/lib/python3.9/site-packages/numpy/polynomial/hermite.py:1403: RankWarning: The fit may be poorly conditioned
#   return pu._fit(hermvander, x, y, deg, rcond, full, w)

# %%
if I <= 20 and paths <= 10:
    plt.plot(S.T, lw=1.5)
    plt.xlabel('time')
    plt.ylabel('index level')

    display_matrix(H.round(2))
    display_matrix(S.round(2))
    display_matrix(V.round(2))
# Out:
# ⎡0   0      0      0      0  ⎤
# ⎢                            ⎥
# ⎢0  8.96    0      0      0  ⎥
# ⎢                            ⎥
# ⎢0  2.31    0      0      0  ⎥
# ⎢                            ⎥
# ⎢0  2.46  17.39  13.98  21.35⎥
# ⎢                            ⎥
# ⎣0   0      0      0      0  ⎦
# ⎡102.0  108.87  119.63  109.33  114.97⎤
# ⎢                                     ⎥
# ⎢102.0  90.04   116.59  113.7   122.71⎥
# ⎢                                     ⎥
# ⎢102.0  96.69   108.54  99.37   103.55⎥
# ⎢                                     ⎥
# ⎢102.0  96.54   81.61   85.02   77.65 ⎥
# ⎢                                     ⎥
# ⎣102.0  109.49  108.4   114.05  105.72⎦
# ⎡0    0      0      0      0  ⎤
# ⎢                             ⎥
# ⎢0  8.96     0      0      0  ⎥
# ⎢                             ⎥
# ⎢0  2.31     0      0      0  ⎥
# ⎢                             ⎥
# ⎢0  18.37  19.32  20.31  21.35⎥
# ⎢                             ⎥
# ⎣0    0      0      0      0  ⎦
